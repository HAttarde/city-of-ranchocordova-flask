# %%
# Clone repository
# !git clone https://github.com/HAttarde/city-of-ranchocordova-flask.git
# %cd city-of-ranchocordova-flask
# Out:
# Cloning into 'city-of-ranchocordova-flask'...
# remote: Enumerating objects: 115, done.
# remote: Counting objects: 100% (115/115), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 115 (delta 20), reused 106 (delta 15), pack-reused 0 (from 0)
# Receiving objects: 100% (115/115), 5.11 MiB | 7.58 MiB/s, done.
# Resolving deltas: 100% (20/20), done.
# /content/city-of-ranchocordova-flask

# %%
# Install packages
print("📦 Installing packages...")
# !pip install -q \
    Flask==3.1.2 \
    Flask_Login==0.6.3 \
    matplotlib \
    python-dotenv==1.1.1 \
    PyPDF2==3.0.1 \
    python-pptx==0.6.23 \
    python-docx==1.1.2 \
    sentence-transformers \
    fastmcp \
    mcp \
    pypdf\
    anthropic \
    langchain_core \
    langchain_openai \
    chromadb \
    pyngrok --no-warn-conflicts
# Out:
# 📦 Installing packages...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 14.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 27.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 24.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 416.2/416.2 kB 38.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 329.0/329.0 kB 31.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.3/390.3 kB 34.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 9.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.7/21.7 MB 134.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 28.9 MB/s eta 0:00:00
# ...

# %%
# Download models BEFORE starting the app (like Dockerfile does)
print("\n🤖 Downloading models (5-10 min on first run)...")
print("This happens once, then models are cached.")
# !python download_models.py
# Out:
# 🤖 Downloading models (5-10 min on first run)...
# This happens once, then models are cached.
# 2026-01-14 15:54:56.719300: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768406096.739290    1004 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768406096.745626    1004 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768406096.761182    1004 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# Setup ngrok
from pyngrok import ngrok
import time

ngrok.set_auth_token("2n87CGDCyvRhLAyPwRBRMD9jVhM_4rQMKTarPEqhjf2eNJA7p")

# %%
# Cleanup
print("\n🧹 Cleaning up old processes...")
ngrok.kill()
# !pkill -9 -f app.py flask 2>/dev/null
time.sleep(3)
# Out:
# 🧹 Cleaning up old processes...

# %%
# Start app (models are already downloaded, so this is fast!)
print("\n🚀 Starting Flask app...")
# !nohup python app.py > flask.log 2>&1 &

# Wait for Flask to initialize
print("We waited a few moments as the flask application is bringing up the Qwen models and reading the chunks from the datasets")
time.sleep(20)  # Shorter wait since models are pre-downloaded
# Out:
# 🚀 Starting Flask app...
# We waited a few moments as the flask application is bringing up the Qwen models and reading the chunks from the datasets

# %%
# Show logs
print("\n📋 App logs:")
# !tail -30 flask.log
# Out:
# 📋 App logs:
#   Benchmarks: 36 utilities
#   PDF Documents: 2 files
#     - 2024AnnualReport_5YearSummary.pdf: 1 pages
#     - CEC-200-2021-005-PO.pdf: 58 pages
#
# ✅ Enhanced datasets loaded
# 📦 Created new ChromaDB collection
# 🔄 Building embeddings (source files changed or first run)...
#   ✓ Extracted 37 benchmark insights
#   ✓ Extracted 10 TOU rate insights
#   ✓ Extracted 19 rebate insights
#
# 📄 Extracting knowledge from 2 PDF documents...
#   ✓ Extracted 1 chunks from 2024AnnualReport_5YearSummary.pdf
#   ✓ Extracted 57 chunks from CEC-200-2021-005-PO.pdf
#   ✓ Total PDF chunks: 58
# ✅ Total RAG chunks: 334
# 🔄 Embedding 334 chunks...
# ✅ Added 334 chunks to ChromaDB
# 💾 Saved source file hashes
# ✅ Embeddings saved to ChromaDB
# ✅ Rancho models initialized with ChromaDB support.
# 🔥 Warm-up complete
#  * Serving Flask app 'app'
#  * Debug mode: off
# ...

# %%
# Create public URL
print("\n🌐 Creating public URL...")
try:
    public_url = ngrok.connect(5000)
    print(f"\n{'='*60}")
    print(f"✅ App is LIVE at: {public_url}")
    print(f"{'='*60}\n")
except Exception as e:
    print(f"❌ Error: {e}")
# Out:
# 🌐 Creating public URL...
#
# ...
# ✅ App is LIVE at: NgrokTunnel: "https://53ad3a4f1ad8.ngrok-free.app" -> "http://localhost:5000"
# ...
